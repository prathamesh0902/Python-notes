# %%
# Code space
sentence = "I love this class - Python. It is amazing!"
nums = [-8, 20, 31, 101, -55, 202, 3, -4]
text = ""
count = 0
list = []
dict = {}

# %% [markdown]
# # Learn

# %% [markdown]
# ## basic operations

# %%
# 1. Variable Assignment
name = "Parth"  # Store a value in a variable.

# 2. Integer Addition
total = 10 + 20  # Add two numbers.

# 3. Subtraction
difference = 50 - 15  # Subtract one number from another.

# 4. Multiplication
product = 6 * 7  # Multiply two values.

# 5. Division
quotient = 20 / 4  # Perform floating-point division.

# 6. Floor Division
result = 20 // 3  # Get the integer quotient.

# 7. Modulus
remainder = 20 % 3  # Find the remainder after division.

# 8. Exponentiation
power = 2 ** 5  # Raise a number to a power.

# 9. Type Conversion to Integer
num = int("100")  # Convert string to integer.

# 10. Type Conversion to Float
price = float("99.99")  # Convert string to float.

# 11. Type Conversion to String
text = str(1234)  # Convert value to string.

# 12. Boolean Conversion
flag = bool(1)  # Convert value to boolean.

# 13. String Concatenation
full_name = "John" + " Doe"  # Join strings together.

# 14. String Repetition
stars = "*" * 5  # Repeat a string multiple times.

# 15. String Length
count = len("Python")  # Count characters in a string.

# 16. String Uppercase
upper_text = "python".upper()  # Convert to uppercase.

# 17. String Lowercase
lower_text = "PYTHON".lower()  # Convert to lowercase.

# 18. String Replace
updated = "Hello World".replace("World", "Python")  # Replace text.

# 19. String Split
words = "apple,banana,mango".split(",")  # Split string into a list.

# 20. String Join
sentence = " ".join(["I", "love", "Python"])  # Join list elements into a string.

# 21. String Strip
clean = "  hello  ".strip()  # Remove leading/trailing spaces.

# 22. String Slicing
part = "Python"[1:4]  # Extract a substring.

# 23. List Creation
numbers = [1, 2, 3]  # Create a list.

# 24. List Append
numbers.append(4)  # Add an item to the end.

# 25. List Insert
numbers.insert(1, 100)  # Insert an element at a specific index.

# 26. List Remove
numbers.remove(2)  # Remove the first matching element.

# 27. List Pop
last = numbers.pop()  # Remove and return the last item.

# 28. List Sort
numbers.sort()  # Sort list in ascending order.
var = list(sorted(number))

# 29. List Reverse
numbers.reverse()  # reverses 'number' in place, returns None
var = list(reversed(number))  # returns a new reversed list

# 30. List Membership
exists = 3 in numbers  # Check if an element exists.

# 31. Tuple Creation
coordinates = (10, 20)  # Create an immutable sequence.

# 32. Tuple Unpacking
x, y = coordinates  # Assign tuple values to variables.

# 33. Dictionary Creation
person = {"name": "Parth", "age": 28}  # Create key-value pairs.

# 34. Dictionary Access
name = person["name"]  # Retrieve a value by key.

# 35. Dictionary Update
person["city"] = "Delhi"  # Add or update a key.

# 36. Dictionary Get
age = person.get("age", 0)  # Access value with default.

# 37. Dictionary Keys
keys = list(person.keys())  # Retrieve all dictionary keys.

# 38. Dictionary Values
values = list(person.values())  # Retrieve all values.

# 39. Set Creation
unique = {1, 2, 3}  # Create a set of unique elements.

# 40. Set Add
unique.add(4)  # Add an element to a set.

# 41. Set Remove
unique.remove(2)  # Remove an element from a set.

# 42. Set Union
combined = {1, 2} | {2, 3}  # Combine unique elements from sets.

# 43. Set Intersection
common = {1, 2, 3} & {2, 3, 4}  # Find common elements.

# 44. If Condition
status = "Adult" if age >= 18 else "Minor"  # Conditional expression.

# 45. For Loop
for i in range(3): print(i)  # Repeat a block of code.

# 46. While Loop
count = 0
while count < 3: count += 1  # Execute while condition is true.

# 47. Function Definition
def greet(name): return f"Hello, {name}"  # Define a reusable function.

# 48. Function Call
message = greet("Parth")  # Invoke a function.

# 49. Exception Handling
try: value = 10 / 0
except ZeroDivisionError: value = None  # Handle runtime errors.

# 50. File Writing
with open("sample.txt", "w") as f: f.write("Hello Python")  # Write text to a file safely.

# %% [markdown]
# ## ❌ Algorithms

# %%
# 1. Linear Search
idx = next((i for i,x in enumerate(arr) if x==target), -1)  # Find target by scanning sequentially.

# 2. Binary Search
while low <= high: mid=(low+high)//2; low,high=(mid+1,high) if arr[mid]<target else (low,mid-1)  # Search sorted array efficiently.

# 3. Bubble Sort
for i in range(n): 
    for j in range(n-i-1): arr[j],arr[j+1]=(arr[j+1],arr[j]) if arr[j]>arr[j+1] else (arr[j],arr[j+1])  # Repeated adjacent swaps.

# 4. Selection Sort
for i in range(len(arr)): arr[i],arr[min(range(i,len(arr)), key=arr.__getitem__)]=arr[min(range(i,len(arr)), key=arr.__getitem__)],arr[i]  # Select minimum each pass.

# 5. Insertion Sort
for i in range(1,len(arr)): key=arr[i]; j=i-1; 
while j>=0 and arr[j]>key: arr[j+1]=arr[j]; j-=1; arr[j+1]=key  # Insert element into sorted part.

# 6. Merge Sort
def merge_sort(a): return a if len(a)<=1 else sorted(a)  # Divide-and-conquer sorting.

# 7. Quick Sort
def quicksort(a): return a if len(a)<=1 else quicksort([x for x in a[1:] if x<=a[0]])+[a[0]]+quicksort([x for x in a[1:] if x>a[0]])  # Partition recursively.

# 8. Heap Sort
import heapq; heapq.heapify(arr); sorted_arr=[heapq.heappop(arr) for _ in range(len(arr))]  # Use heap structure.

# 9. Counting Sort
count=[0]*(max(arr)+1); [count.__setitem__(x,count[x]+1) for x in arr]  # Sort integers by frequency.

# 10. Radix Sort
for exp in [1,10,100]: arr=sorted(arr,key=lambda x:(x//exp)%10)  # Digit-by-digit sorting.

# 11. Fibonacci DP
fib=[0,1]; [fib.append(fib[-1]+fib[-2]) for _ in range(2,n+1)]  # Dynamic programming approach.

# 12. Fibonacci Memoization
memo={}; fib=lambda n:n if n<2 else memo.setdefault(n,fib(n-1)+fib(n-2))  # Top-down caching.

# 13. Factorial Recursion
def fact(n): return 1 if n<=1 else n*fact(n-1)  # Recursive factorial.

# 14. GCD Euclidean Algorithm
while b: a,b=b,a%b  # Compute greatest common divisor.

# 15. LCM
lcm = a*b//__import__('math').gcd(a,b)  # Least common multiple.

# 16. Sieve of Eratosthenes
prime=[True]*(n+1); [prime.__setitem__(j,False) for i in range(2,int(n**0.5)+1) if prime[i] for j in range(i*i,n+1,i)]  # Generate primes.

# 17. Prime Check
is_prime = n>1 and all(n%i for i in range(2,int(n**0.5)+1))  # Verify primality.

# 18. Power by Squaring
def power(x,n): return 1 if n==0 else power(x*x,n//2) if n%2==0 else x*power(x,n-1)  # Fast exponentiation.

# 19. Kadane's Algorithm
curr=max_sum=arr[0]; [exec("curr=max(x,curr+x); max_sum=max(max_sum,curr)") for x in arr[1:]]  # Maximum subarray sum.

# 20. Two Sum
seen={}; result=next(((seen[target-x],i) for i,x in enumerate(arr) if target-x in seen or not seen.setdefault(x,i)),None)  # Find pair with target sum.

# 21. Sliding Window Sum
window=sum(arr[:k]); best=max(window, *(window:=window-arr[i-k]+arr[i] for i in range(k,len(arr))))  # Fixed-size window optimization.

# 22. Prefix Sum
prefix=[0]; [prefix.append(prefix[-1]+x) for x in arr]  # Precompute cumulative sums.

# 23. Difference Array
diff=[0]*(n+1); diff[l]+=v; diff[r+1]-=v  # Efficient range updates.

# 24. Binary Tree DFS (Preorder)
def dfs(node): return [] if not node else [node.val]+dfs(node.left)+dfs(node.right)  # Depth-first traversal.

# 25. Binary Tree BFS
from collections import deque; q=deque([root])  # Level-order traversal.

# 26. Graph DFS
def dfs(v): visited.add(v); [dfs(nei) for nei in graph[v] if nei not in visited]  # Explore deeply.

# 27. Graph BFS
q=deque([start]); visited={start}  # Explore level by level.

# 28. Topological Sort
from collections import deque; q=deque([n for n,d in indegree.items() if d==0])  # DAG ordering.

# 29. Union Find - Find
def find(x): parent.setdefault(x,x); parent[x]=find(parent[x]) if parent[x]!=x else x; return parent[x]  # Path compression.

# 30. Union Find - Union
def union(x,y): parent[find(x)] = find(y)  # Merge disjoint sets.

# 31. Dijkstra's Algorithm
heap=[(0,start)]  # Shortest path using priority queue.

# 32. Bellman-Ford
for _ in range(V-1): [exec("dist[v]=min(dist[v],dist[u]+w)") for u,v,w in edges]  # Handle negative edges.

# 33. Floyd-Warshall
for k in range(n): 
    for i in range(n): 
        for j in range(n): dist[i][j]=min(dist[i][j],dist[i][k]+dist[k][j])  # All-pairs shortest path.

# 34. Kruskal's Algorithm
edges.sort(key=lambda x:x[2])  # Minimum spanning tree using sorting.

# 35. Prim's Algorithm
heap=[(0,start)]  # Minimum spanning tree using heap.

# 36. Backtracking - Subsets
def subsets(i,path): pass  # Generate all subsets recursively.

# 37. Backtracking - Permutations
def permute(path,used): pass  # Explore all orderings.

# 38. N-Queens
def solve(row): pass  # Place queens safely using recursion.

# 39. Rat in a Maze
def maze(x,y): pass  # Explore valid paths.

# 40. Coin Change DP
dp=[0]+[float('inf')]*amount  # Minimum coins dynamic programming.

# 41. 0/1 Knapsack
dp=[0]*(capacity+1)  # Maximize value within capacity.

# 42. Longest Common Subsequence
dp=[[0]*(m+1) for _ in range(n+1)]  # Compare two sequences.

# 43. Longest Increasing Subsequence
import bisect; lis=[]  # Optimize LIS to O(n log n).

# 44. Edit Distance
dp=[[0]*(m+1) for _ in range(n+1)]  # Minimum operations between strings.

# 45. Matrix Chain Multiplication
dp=[[0]*n for _ in range(n)]  # Optimize matrix multiplication cost.

# 46. Reservoir Sampling
sample=[]  # Randomly sample from data streams.

# 47. Boyer-Moore Majority Vote
count=candidate=0  # Find majority element in O(1) space.

# 48. KMP Pattern Matching
lps=[0]*len(pattern)  # Efficient substring search.

# 49. Rabin-Karp
hash_pat=hash(pattern); hash_txt=hash(text[:m])  # Rolling hash matching.

# 50. Trie Insert
node=trie; [node.setdefault(ch,{}) or (node:=node[ch]) for ch in word]; node["#"]=True  # Prefix tree insertion.

# %% [markdown]
# ## ❗intermediate level topics

# %%
# 1. List Comprehension
squares = [x**2 for x in range(10)]  # Create squared values using list comprehension.

# 2. Dictionary Comprehension
square_map = {x: x**2 for x in range(5)}  # Build dictionaries concisely.

# 3. Set Comprehension
unique_lengths = {len(word) for word in ["apple", "cat", "banana"]}  # Generate sets dynamically.

# 4. Generator Expression
gen = (x*x for x in range(5))  # Produce values lazily.

# 5. Enumerate
for idx, val in enumerate(['a', 'b'], start=1): print(idx, val)  # Access index and value together.

# 6. Zip
pairs = list(zip([1,2], ['a','b']))  # Combine iterables element-wise.

# 7. Unzip
nums, chars = zip(*pairs)  # Reverse zip operation.

# 8. Lambda Function
add = lambda x, y: x + y  # Define anonymous functions.

# 9. Map
result = list(map(str.upper, ['python', 'code']))  # Apply function to all elements.

# 10. Filter
evens = list(filter(lambda x: x%2==0, range(10)))  # Filter iterable items.

# 11. Sorted with Key
names = sorted(['Tom', 'Alex', 'John'], key=len)  # Customize sorting behavior.

# 12. Any
flag = any(x > 10 for x in [3, 5, 15])  # Check if any condition is true.

# 13. All
valid = all(x > 0 for x in [1, 2, 3])  # Verify all conditions hold.

# 14. *args
def total(*args): return sum(args)  # Accept variable positional arguments.

# 15. **kwargs
def display(**kwargs): print(kwargs)  # Accept variable keyword arguments.

# 16. Decorator
def deco(func): return lambda: f"Hello {func()}"  # Modify function behavior.

# 17. Closure
def outer(x): return lambda y: x + y  # Retain enclosing scope variables.

# 18. Iterator Protocol
it = iter([1,2,3]); first = next(it)  # Iterate manually.

# 19. Custom Generator
def countdown(n): yield from range(n, 0, -1)  # Yield values efficiently.

# 20. Context Manager
with open("file.txt", "w") as f: f.write("Hello")  # Manage resources automatically.

# 21. Exception Handling
try: 1/0
except ZeroDivisionError: print("Cannot divide")  # Catch runtime errors.

# 22. Raise Exception
if False: raise ValueError("Invalid input")  # Trigger custom exceptions.

# 23. Assertions
assert 2 + 2 == 4  # Validate assumptions during development.

# 24. Dataclass
from dataclasses import dataclass; @dataclass class User: name:str  # Reduce boilerplate.

# 25. NamedTuple
from collections import namedtuple; Point = namedtuple("Point", "x y")  # Lightweight immutable objects.

# 26. Counter
from collections import Counter; freq = Counter("banana")  # Count occurrences.

# 27. DefaultDict
from collections import defaultdict; d = defaultdict(list)  # Avoid missing key errors.

# 28. Deque
from collections import deque; q = deque([1,2]); q.appendleft(0)  # Efficient double-ended queue.

# 29. Chain
from itertools import chain; merged = list(chain([1,2], [3,4]))  # Flatten iterables.

# 30. Groupby
from itertools import groupby; groups = {k:list(v) for k,v in groupby("aaabb")}  # Group consecutive items.

# 31. Permutations
from itertools import permutations; perms = list(permutations([1,2,3],2))  # Generate arrangements.

# 32. Combinations
from itertools import combinations; comb = list(combinations([1,2,3],2))  # Generate selections.

# 33. Partial Functions
from functools import partial; square = partial(pow, exp=2)  # Pre-fill function arguments.

# 34. Reduce
from functools import reduce; product = reduce(lambda x,y:x*y,[1,2,3])  # Aggregate iterables.

# 35. LRU Cache
from functools import lru_cache; @lru_cache() def fib(n): return n if n<2 else fib(n-1)+fib(n-2)  # Memoize function results.

# 36. Property Decorator
class Temp: c=0; fahrenheit=property(lambda self:self.c*9/5+32)  # Define computed attributes.

# 37. Static Method
class Math: square = staticmethod(lambda x:x*x)  # Define utility methods.

# 38. Class Method
class Person: count=0; inc=classmethod(lambda cls:setattr(cls,'count',cls.count+1))  # Operate on class state.

# 39. Inheritance
class Animal: pass; class Dog(Animal): pass  # Reuse functionality through inheritance.

# 40. Magic Method
class Vector: __repr__ = lambda self:"Vector()"  # Customize object representation.

# 41. Regex Search
import re; match = re.search(r"\d+", "ID123")  # Find patterns in strings.

# 42. Regex Substitution
clean = re.sub(r"\s+", "-", "hello world")  # Replace matching text.

# 43. JSON Serialization
import json; text = json.dumps({"name":"Parth"})  # Convert objects to JSON.

# 44. JSON Deserialization
obj = json.loads(text)  # Parse JSON into Python objects.

# 45. Pathlib
from pathlib import Path; exists = Path("file.txt").exists()  # Work with filesystem paths.

# 46. Type Hints
def greet(name:str) -> str: return f"Hi {name}"  # Improve readability and tooling.

# 47. Walrus Operator
if (n := len("Python")) > 5: print(n)  # Assign within expressions.

# 48. Structural Pattern Matching
match 2: case 1: print("One"); case 2: print("Two")  # Match values elegantly.

# 49. ThreadPoolExecutor
from concurrent.futures import ThreadPoolExecutor; ThreadPoolExecutor().map(print,[1,2])  # Execute tasks concurrently.

# 50. Async/Await
import asyncio; async def hello(): return "Hi"; asyncio.run(hello())  # Perform asynchronous programming.

# %% [markdown]
# ## intuitive thinking

# %%
# 1. Find the second largest number.
nums = [5, 8, 2, 9, 1]; second = sorted(set(nums))[-2]  # Remove duplicates, sort, and pick second largest.

# 2. Check if two strings are anagrams.
a, b = "listen", "silent"; is_anagram = sorted(a) == sorted(b)  # Compare sorted characters.

# 3. Count vowels in a sentence.
text = "I love Python"; count = sum(c.lower() in "aeiou" for c in text)  # Combine iteration and conditions.

# 4. Reverse words but not characters.
s = "Python is fun"; result = " ".join(s.split()[::-1])  # Split, reverse, and join.

# 5. Find duplicate elements.
nums = [1,2,3,2,4,1]; dup = [x for x in set(nums) if nums.count(x) > 1]  # Use set and frequency.

# 6. Flatten a nested list.
nested = [[1,2],[3,4],[5]]; flat = [x for sub in nested for x in sub]  # Nested list comprehension.

# 7. Group words by length.
words = ["cat","apple","dog"]; groups = {n:[w for w in words if len(w)==n] for n in {len(w) for w in words}}  # Combine comprehensions.

# 8. Find missing number from 1 to n.
nums = [1,2,4,5]; n = 5; missing = n*(n+1)//2 - sum(nums)  # Formula plus aggregation.

# 9. Check palindrome ignoring spaces/case.
s = "Never Odd Or Even"; clean = s.replace(" ","").lower(); is_pal = clean == clean[::-1]  # Normalize then compare.

# 10. Rotate list by k positions.
arr = [1,2,3,4,5]; k = 2; rotated = arr[-k:] + arr[:-k]  # Slice and concatenate.

# 11. Find common elements in lists.
a,b = [1,2,3],[2,3,4]; common = list(set(a) & set(b))  # Use set intersection.

# 12. Remove duplicates preserving order.
nums = [1,2,1,3,2]; unique = list(dict.fromkeys(nums))  # Leverage dictionary ordering.

# 13. Capitalize first letter of each word.
text = "python is awesome"; result = " ".join(w.capitalize() for w in text.split())  # Split-transform-join.

# 14. Frequency of characters.
s = "banana"; freq = {c:s.count(c) for c in set(s)}  # Build frequency dictionary.

# 15. Find longest word.
words = ["cat","elephant","dog"]; longest = max(words, key=len)  # Use custom key.

# 16. Count occurrences of each word.
text = "cat dog cat"; counts = {w:text.split().count(w) for w in set(text.split())}  # Combine split and count.

# 17. Merge dictionaries summing values.
a,b = {"x":1},{"x":2,"y":3}; merged = {k:a.get(k,0)+b.get(k,0) for k in set(a)|set(b)}  # Merge intelligently.

# 18. Find pairs with target sum.
nums,target=[2,7,11,15],9; pairs=[(x,target-x) for x in nums if target-x in nums and x<target-x]  # Use conditions.

# 19. Separate even and odd numbers.
nums=[1,2,3,4]; even=[x for x in nums if x%2==0]; odd=[x for x in nums if x%2]  # Partition list.

# 20. Find all indices of an element.
nums=[1,2,1,3,1]; idx=[i for i,x in enumerate(nums) if x==1]  # Combine enumerate and filtering.

# 21. Convert matrix to transpose.
matrix=[[1,2],[3,4]]; transpose=list(map(list, zip(*matrix)))  # Zip with unpacking.

# 22. Find row sums in matrix.
matrix=[[1,2],[3,4]]; sums=[sum(row) for row in matrix]  # Aggregate nested lists.

# 23. Extract digits from string.
s="A1B23C"; digits="".join(c for c in s if c.isdigit())  # Filter characters.

# 24. Validate strong password.
pwd="P@ss123"; valid=len(pwd)>=8 and any(c.isupper() for c in pwd) and any(c.isdigit() for c in pwd)  # Multiple checks.

# 25. Convert list to dictionary with indices.
items=["a","b","c"]; mapping={i:v for i,v in enumerate(items)}  # Enumerate into dictionary.

# 26. Find cumulative sums.
nums=[1,2,3]; total=0; cumulative=[(total:=total+x) for x in nums]  # Walrus operator usage.

# 27. Remove punctuation.
import string; s="Hi, Python!"; clean="".join(c for c in s if c not in string.punctuation)  # Filter symbols.

# 28. Check subset relation.
a,b={1,2},{1,2,3}; is_subset=a <= b  # Use set operations.

# 29. Find max occurring element.
nums=[1,2,2,3]; frequent=max(set(nums), key=nums.count)  # Frequency-based selection.

# 30. Replace negatives with zero.
nums=[1,-2,3,-1]; result=[max(0,x) for x in nums]  # Apply transformation.

# 31. Count words longer than n.
words=["cat","apple","elephant"]; count=sum(len(w)>5 for w in words)  # Boolean summation.

# 32. Find unique characters in string.
s="programming"; unique=[c for c in s if s.count(c)==1]  # Frequency filtering.

# 33. Sort tuples by second value.
pairs=[("a",3),("b",1)]; sorted_pairs=sorted(pairs,key=lambda x:x[1])  # Custom sorting.

# 34. Find intersection preserving order.
a,b=[1,2,3,2],[2,3]; result=[x for x in a if x in b]  # Ordered filtering.

# 35. Reverse dictionary.
d={"a":1,"b":2}; rev={v:k for k,v in d.items()}  # Swap keys and values.

# 36. Find average excluding extremes.
nums=[1,2,3,4,5]; avg=sum(sorted(nums)[1:-1])/len(nums[1:-1])  # Slice and aggregate.

# 37. Chunk list into groups.
nums=[1,2,3,4,5]; chunks=[nums[i:i+2] for i in range(0,len(nums),2)]  # Step through list.

# 38. Convert binary string to decimal.
binary="1011"; decimal=int(binary,2)  # Built-in base conversion.

# 39. Check if list is sorted.
nums=[1,2,3]; is_sorted=nums==sorted(nums)  # Compare with sorted copy.

# 40. Zip names with scores.
names=["A","B"]; scores=[90,80]; report=dict(zip(names,scores))  # Combine related data.

# 41. Create acronym from phrase.
phrase="Portable Network Graphics"; acronym="".join(w[0] for w in phrase.split())  # Extract initials.

# 42. Find words starting with vowel.
words=["apple","cat","orange"]; result=[w for w in words if w[0].lower() in "aeiou"]  # Filter by first letter.

# 43. Replace None values.
data=[1,None,3]; cleaned=[x if x is not None else 0 for x in data]  # Conditional transformation.

# 44. Count uppercase letters.
text="PyTHon"; count=sum(c.isupper() for c in text)  # Use boolean counting.

# 45. Find symmetric difference.
a,b={1,2,3},{3,4}; diff=a ^ b  # Elements unique to each set.

# 46. Check if all elements are unique.
nums=[1,2,3]; unique=len(nums)==len(set(nums))  # Compare lengths.

# 47. Build nested dictionary from tuples.
pairs=[("A",1),("B",2)]; d={k:{"value":v} for k,v in pairs}  # Create structured data.

# 48. Find shortest word.
words=["python","AI","code"]; shortest=min(words,key=len)  # Minimum using key.

# 49. Compute weighted average.
scores=[80,90]; weights=[0.4,0.6]; avg=sum(s*w for s,w in zip(scores,weights))/sum(weights)  # Combine zip and aggregation.

# 50. Generate multiplication table dictionary.
table={i:[i*j for j in range(1,6)] for i in range(1,6)}  # Nested comprehension for structured output.

# %% [markdown]
# ## interview questions

# %%
# 1. Reverse a String
s = "python"; reversed_s = s[::-1]  # Reverse using slicing.

# 2. Check Palindrome
s = "madam"; is_palindrome = s == s[::-1]  # Compare with reversed string.

# 3. Find Factorial
def factorial(n): return 1 if n <= 1 else n * factorial(n - 1)  # Recursive factorial.

# 4. Generate Fibonacci Series
a, b, fib = 0, 1, []
for _ in range(5): fib.append(a); a, b = b, a + b  # Generate Fibonacci numbers.

# 5. Check Prime Number
n = 29; is_prime = n > 1 and all(n % i for i in range(2, int(n**0.5) + 1))  # Efficient prime check.

# 6. Find Largest Element
nums = [4, 9, 1, 7]; largest = max(nums)  # Find maximum value.

# 7. Find Smallest Element
smallest = min(nums)  # Find minimum value.

# 8. Find Second Largest Element
second = sorted(set(nums))[-2]  # Remove duplicates and sort.

# 9. Remove Duplicates from List
nums = [1,2,2,3,1]; unique = list(dict.fromkeys(nums))  # Preserve order.

# 10. Count Frequency of Elements
freq = {x: nums.count(x) for x in set(nums)}  # Build frequency map.

# 11. Find Missing Number
arr = [1,2,4,5]; n = 5
missing = n * (n + 1) // 2 - sum(arr)  # Use arithmetic formula.

# 12. Find Common Elements
a, b = [1,2,3], [2,3,4]
common = list(set(a) & set(b))  # Set intersection.

# 13. Merge Two Dictionaries
d1, d2 = {"a":1}, {"b":2}
merged = {**d1, **d2}  # Dictionary unpacking.

# 14. Flatten Nested List
nested = [[1,2],[3,4]]
flat = [x for sub in nested for x in sub]  # Nested comprehension.

# 15. Count Vowels
text = "Interview"
count = sum(c.lower() in "aeiou" for c in text)  # Boolean summation.

# 16. Check Anagram
a, b = "listen", "silent"
is_anagram = sorted(a) == sorted(b)  # Compare sorted characters.

# 17. Reverse Words in Sentence
s = "Python is fun"
result = " ".join(s.split()[::-1])  # Reverse word order.

# 18. Find Duplicate Elements
nums = [1,2,2,3,1]
duplicates = [x for x in set(nums) if nums.count(x) > 1]  # Frequency filtering.

# 19. Find All Even Numbers
evens = [x for x in range(20) if x % 2 == 0]  # List comprehension.

# 20. Find All Odd Numbers
odds = [x for x in range(20) if x % 2 != 0]  # Conditional filtering.

# 21. Swap Two Variables
a, b = 10, 20
a, b = b, a  # Pythonic swap.

# 22. Check Armstrong Number
n = 153
armstrong = n == sum(int(d)**len(str(n)) for d in str(n))  # Digit power sum.

# 23. Find GCD
import math
gcd = math.gcd(24, 36)  # Greatest common divisor.

# 24. Find LCM
a, b = 12, 18
lcm = a * b // math.gcd(a, b)  # Least common multiple.

# 25. Count Words in String
sentence = "Python coding interview"
word_count = len(sentence.split())  # Split and count.

# 26. Find First Non-Repeating Character
s = "swiss"
char = next((c for c in s if s.count(c) == 1), None)  # Generator expression.

# 27. Find Character Frequency
freq = {c: s.count(c) for c in set(s)}  # Frequency dictionary.

# 28. Sort List of Tuples
pairs = [("a",3), ("b",1)]
sorted_pairs = sorted(pairs, key=lambda x: x[1])  # Sort by second element.

# 29. Binary Search
arr = [1,3,5,7,9]; target = 7
low, high = 0, len(arr)-1
while low <= high:
    mid = (low + high) // 2
    if arr[mid] == target: break
    elif arr[mid] < target: low = mid + 1
    else: high = mid - 1  # O(log n) search.

# 30. Bubble Sort
arr = [5,3,1]
for i in range(len(arr)):
    for j in range(len(arr)-i-1):
        if arr[j] > arr[j+1]:
            arr[j], arr[j+1] = arr[j+1], arr[j]  # Adjacent swaps.

# 31. Selection Sort
arr = [3,1,2]
for i in range(len(arr)):
    m = i
    for j in range(i+1, len(arr)):
        if arr[j] < arr[m]:
            m = j
    arr[i], arr[m] = arr[m], arr[i]  # Select minimum.

# 32. Insertion Sort
arr = [4,2,1]
for i in range(1, len(arr)):
    key, j = arr[i], i-1
    while j >= 0 and arr[j] > key:
        arr[j+1] = arr[j]
        j -= 1
    arr[j+1] = key  # Insert into sorted section.

# 33. Quick Sort
def quicksort(arr):
    return arr if len(arr)<=1 else quicksort([x for x in arr[1:] if x<=arr[0]]) + [arr[0]] + quicksort([x for x in arr[1:] if x>arr[0]])  # Divide and conquer.

# 34. Merge Sort
def mergesort(arr):
    return sorted(arr) if len(arr) > 1 else arr  # Simplified merge sort concept.

# 35. Two Sum Problem
nums = [2,7,11,15]; target = 9
seen = {}
for i, x in enumerate(nums):
    if target - x in seen:
        result = [seen[target-x], i]
        break
    seen[x] = i  # Hash map lookup.

# 36. Maximum Subarray Sum
nums = [-2,1,-3,4,-1,2,1]
curr = best = nums[0]
for x in nums[1:]:
    curr = max(x, curr + x)
    best = max(best, curr)  # Kadane's algorithm.

# 37. Rotate List
nums = [1,2,3,4,5]
k = 2
rotated = nums[-k:] + nums[:-k]  # Right rotation.

# 38. Check Balanced Parentheses
s = "{[]}"
stack, mp = [], {')':'(', ']':'[', '}':'{'}
valid = True
for ch in s:
    if ch in "([{": stack.append(ch)
    elif not stack or stack.pop() != mp[ch]:
        valid = False; break  # Stack-based validation.

# 39. Decimal to Binary
binary = bin(10)[2:]  # Convert integer to binary string.

# 40. Binary to Decimal
decimal = int("1010", 2)  # Base conversion.

# 41. Matrix Transpose
matrix = [[1,2],[3,4]]
transpose = list(map(list, zip(*matrix)))  # Unpack and zip.

# 42. Find Row Sums
row_sums = [sum(row) for row in matrix]  # Aggregate matrix rows.

# 43. Check Substring
exists = "view" in "interview"  # Membership test.

# 44. Remove Punctuation
import string
text = "Hello, World!"
clean = "".join(c for c in text if c not in string.punctuation)  # Character filtering.

# 45. Count Uppercase Letters
text = "PyTHon"
uppercase = sum(c.isupper() for c in text)  # Boolean counting.

# 46. Zip Two Lists
names = ["A", "B"]; scores = [90, 85]
result = dict(zip(names, scores))  # Pair related values.

# 47. Chunk List
nums = [1,2,3,4,5]
chunks = [nums[i:i+2] for i in range(0, len(nums), 2)]  # Split into groups.

# 48. Check if List is Sorted
nums = [1,2,3]
is_sorted = nums == sorted(nums)  # Compare with sorted version.

# 49. Find Majority Element
nums = [2,2,1,2]
majority = max(set(nums), key=nums.count)  # Most frequent element.

# 50. Generate Multiplication Table
table = {i: [i*j for j in range(1, 11)] for i in range(1, 6)}  # Nested comprehension.

# %% [markdown]
# ## longer interview questions

# %%
# 1. Return indices of two numbers that sum to target.
nums, target = [2,7,11,15], 9
seen = {}; ans = next(([seen[target-x], i] for i,x in enumerate(nums) if target-x in seen or not seen.setdefault(x,i)), None)  # Hash map + lookup.

# 2. Find the first non-repeating character.
s = "swiss"
char = next((c for c in s if s.count(c) == 1), None)  # Frequency check + scan.

# 3. Check if two strings are anagrams.
a, b = "listen", "silent"
is_anagram = len(a) == len(b) and sorted(a) == sorted(b)  # Length check + sort.

# 4. Move all zeros to the end.
nums = [0,1,0,3,12]
result = [x for x in nums if x != 0] + [0] * nums.count(0)  # Filter + append zeros.

# 5. Find duplicate numbers.
nums = [1,2,3,2,1,4]
duplicates = [x for x in set(nums) if nums.count(x) > 1]  # Unique values + count.

# 6. Remove duplicates preserving order.
nums = [1,2,1,3,2]
unique = list(dict.fromkeys(nums))  # Dictionary ordering.

# 7. Reverse words in a sentence.
s = "Python is awesome"
result = " ".join(s.split()[::-1])  # Split + reverse + join.

# 8. Count vowels in a string.
s = "Interview Preparation"
count = sum(c.lower() in "aeiou" for c in s)  # Normalize + count.

# 9. Find the missing number from 1 to n.
nums, n = [1,2,4,5], 5
missing = n*(n+1)//2 - sum(nums)  # Formula + subtraction.

# 10. Check palindrome ignoring spaces.
s = "Never Odd Or Even"
clean = s.replace(" ", "").lower(); is_pal = clean == clean[::-1]  # Normalize + compare.

# 11. Find common elements in two lists.
a, b = [1,2,3], [2,3,4]
common = list(set(a) & set(b))  # Convert to sets + intersect.

# 12. Find second largest number.
nums = [4,8,2,9,8]
second = sorted(set(nums))[-2]  # Remove duplicates + sort.

# 13. Rotate list to the right by k.
nums, k = [1,2,3,4,5], 2
rotated = nums[-k:] + nums[:-k]  # Slice + concatenate.

# 14. Count frequency of words.
text = "cat dog cat bird"
freq = {w: text.split().count(w) for w in set(text.split())}  # Split + count.

# 15. Find the longest word.
words = ["cat","elephant","dog"]
longest = max(words, key=len)  # Use length-based comparison.

# 16. Find all indices of a value.
nums = [1,2,1,3,1]
indices = [i for i,x in enumerate(nums) if x == 1]  # Enumerate + filter.

# 17. Flatten a nested list.
nested = [[1,2],[3,4],[5]]
flat = [x for sub in nested for x in sub]  # Nested iteration.

# 18. Capitalize each word.
s = "python interview prep"
result = " ".join(word.capitalize() for word in s.split())  # Split + transform.

# 19. Replace negative numbers with zero.
nums = [1,-2,3,-4]
cleaned = [max(0, x) for x in nums]  # Conditional transformation.

# 20. Find the majority element.
nums = [2,2,1,2,3]
majority = max(set(nums), key=nums.count)  # Unique values + frequency.

# 21. Check if a list is sorted.
nums = [1,2,3,4]
is_sorted = nums == sorted(nums)  # Compare against sorted copy.

# 22. Merge two dictionaries by summing values.
a, b = {"x":1}, {"x":2,"y":3}
merged = {k: a.get(k,0) + b.get(k,0) for k in set(a)|set(b)}  # Union + aggregation.

# 23. Find symmetric difference of sets.
a, b = {1,2,3}, {3,4,5}
diff = a ^ b  # Elements unique to each set.

# 24. Extract digits from a string.
s = "AB12CD34"
digits = "".join(c for c in s if c.isdigit())  # Filter + join.

# 25. Find shortest word.
words = ["python","AI","coding"]
shortest = min(words, key=len)  # Length comparison.

# 26. Create acronym from phrase.
phrase = "Portable Network Graphics"
acronym = "".join(word[0] for word in phrase.split())  # Split + extract initials.

# 27. Chunk a list into groups of size 3.
nums = [1,2,3,4,5,6,7]
chunks = [nums[i:i+3] for i in range(0, len(nums), 3)]  # Range + slicing.

# 28. Find max occurring character.
s = "banana"
char = max(set(s), key=s.count)  # Unique characters + count.

# 29. Reverse dictionary keys and values.
d = {"a":1,"b":2}
rev = {v:k for k,v in d.items()}  # Swap key-value pairs.

# 30. Count uppercase letters.
s = "PyTHon"
count = sum(c.isupper() for c in s)  # Boolean summation.

# 31. Check if all elements are unique.
nums = [1,2,3,4]
is_unique = len(nums) == len(set(nums))  # Compare lengths.

# 32. Find average excluding min and max.
nums = [1,2,3,4,5]
avg = sum(sorted(nums)[1:-1]) / len(nums[1:-1])  # Sort + slice + average.

# 33. Convert binary string to decimal.
binary = "1011"
decimal = int(binary, 2)  # Base conversion.

# 34. Convert decimal to binary.
n = 11
binary = bin(n)[2:]  # Built-in conversion.

# 35. Zip names with scores.
names, scores = ["A","B"], [90,85]
report = dict(zip(names, scores))  # Pair corresponding values.

# 36. Find words starting with vowels.
words = ["apple","cat","orange"]
vowel_words = [w for w in words if w[0].lower() in "aeiou"]  # Filter by condition.

# 37. Remove punctuation from text.
import string
text = "Hello, World!"
clean = "".join(c for c in text if c not in string.punctuation)  # Filter + join.

# 38. Check subset relationship.
a, b = {1,2}, {1,2,3}
is_subset = a <= b  # Set comparison.

# 39. Find cumulative sums.
nums = [1,2,3]
total = 0; cumulative = [(total := total + x) for x in nums]  # Running total.

# 40. Sort tuples by second element.
pairs = [("a",3),("b",1),("c",2)]
sorted_pairs = sorted(pairs, key=lambda x: x[1])  # Custom sort.

# 41. Count words longer than 4 characters.
words = ["cat","apple","banana"]
count = sum(len(w) > 4 for w in words)  # Predicate + count.

# 42. Find pair with maximum sum.
nums = [5,1,8,3]
pair_sum = sum(sorted(nums)[-2:])  # Sort + aggregate.

# 43. Build index-value mapping.
items = ["x","y","z"]
mapping = {i:v for i,v in enumerate(items)}  # Enumerate + dictionary.

# 44. Validate simple password rules.
pwd = "Pass1234"
valid = len(pwd)>=8 and any(c.isdigit() for c in pwd) and any(c.isupper() for c in pwd)  # Multiple conditions.

# 45. Find intersection preserving order.
a, b = [1,2,3,2], [2,3]
result = [x for x in a if x in b]  # Membership + filtering.

# 46. Compute weighted average.
scores, weights = [80,90], [0.4,0.6]
avg = sum(s*w for s,w in zip(scores, weights)) / sum(weights)  # Zip + aggregate.

# 47. Transpose a matrix.
matrix = [[1,2],[3,4]]
transpose = list(map(list, zip(*matrix)))  # Unpack + zip.

# 48. Find row sums in a matrix.
matrix = [[1,2],[3,4]]
row_sums = [sum(row) for row in matrix]  # Iterate + sum.

# 49. Group words by length.
words = ["cat","dog","apple"]
groups = {n:[w for w in words if len(w)==n] for n in {len(w) for w in words}}  # Nested comprehensions.

# 50. Generate multiplication table for 1–5.
table = {i:[i*j for j in range(1,6)] for i in range(1,6)}  # Nested loops in dictionary comprehension.

# %% [markdown]
# # fill your code

# %% [markdown]
# ## Level 1

# %%
# Python Quiz (Semester 1 Level)
### 1. Count Even Numbers in a List
nums = [12, 5, 8, 19, 20, 6]
count = 0
# fill your code here
print(count)      # Output: 4

**Solution**
for num in nums:
    if num % 2 == 0:
        count += 1
output = len([c for c in nums if c % 2 == 0])
output = sum(c % 2 == 0 for c in nums)  

### 2. Find the Largest Word
words = ["cat", "elephant", "dog", "tiger"]
# fill your code here
print(longest)    # Output: elephant

**Solution**
longest = words[0]
for word in words:
    if len(word) > len(longest):
        longest = word
output = max(words, key=len)
output = max([word for word in words], key=len, default="")

### 3. Count Vowels
text = "Python Programming"
count = 0
# fill your code here
print(count)      # Output: 4

**Solution**
for ch in text.lower():
    if ch in "aeiou":
        count += 1
output = sum(c.lower() in "aeiou" for c in s)    

### 4. Create Squares Dictionary
nums = [1, 2, 3, 4]
squares = {}
# fill your code here
print(squares)    # Output: {1:1,2:4,3:9,4:16}

**Solution**
for num in nums:
    squares[num] = num ** 2
output = {i: i * i for i in nums}

### 5. Find Common Elements
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]
common = []
# fill your code here
print(common)     # Output: [3, 4]

**Solution**
for num in list1:
    if num in list2:
        common.append(num)
        
### 6. Reverse Each Word
sentence = "I love Python"
result = []
# fill your code here
print(" ".join(result))    # Output: I evol nohtyP

**Solution**
for word in sentence.split():
    result.append(word[::-1])
output = " ".join([ word[::-1] for word in sentence.split()])

### 7. Count Positive Numbers
nums = [-2, 5, 8, -1, 0, 3]
count = 0
# fill your code here
print(count)      # Output: 3

**Solution**
for num in nums:
    if num > 0:
        count += 1
output = len([no for no in nums if no >= 0])
output = sum(c > 0 for c in nums)

### 8. Find Student with Highest Marks
marks = {"A": 80, "B": 92, "C": 75}
# fill your code here
print(topper)     # Output: B

**Solution**
topper = max(marks, key=marks.get)
'''---  OR ---'''
count = 0
var = ''

for i in marks:
    if marks[i] > count:
        count = marks[i]
        var = i
var
'''
topper = max(marks.key, key=marks.get)		# gives key for max value
max(marks.keys())				# give highest alphabet
max(marks.values())      		         # gives max value / marks
'''
### 9. Remove Duplicate Characters
text = "programming"
result = ""
# fill your code here
print(result)     # Output: progamin

**Solution**
for ch in text:
    if ch not in result:
        result += ch
        
### 10. Sum of Digits
number = 4825
total = 0
# fill your code here
print(total)      # Output: 19

**Solution**
for digit in str(number):
    total += int(digit)
    
### 11. Filter Long Words
words = ["cat", "elephant", "sun", "banana"]
result = []
# fill your code here
print(result)     # Output: ['elephant', 'banana']

**Solution**
for word in words:
    if len(word) > 5:
        result.append(word)
output = [word for word in sentence.split() if len(word) > 5] 

### 12. Count Character Frequency
text = "banana"
freq = {}
# fill your code here
print(freq)       # Output: {'b':1,'a':3,'n':2}

**Solution**
for ch in text:
    freq[ch] = freq.get(ch, 0) + 1
    
### 13. Check Palindrome
word = "madam"
# fill your code here
print(is_palindrome)    # Output: True

**Solution**
is_palindrome = word == word[::-1]

### 14. Find Multiples of 3
nums = [2,3,6,7,9,12]
result = []
# fill your code here
print(result)     # Output: [3,6,9,12]

**Solution**
for num in nums:
    if num % 3 == 0:
        result.append(num)
        
### 15. Capitalize First Letter
sentence = "python is fun"
result = []
# fill your code here
print(" ".join(result))     # Output: Python Is Fun

**Solution**
for word in sentence.split():
    result.append(word.capitalize())
    
### 16. Average of List
nums = [10, 20, 30, 40]
# fill your code here
print(avg)      # Output: 25.0

**Solution**
avg = sum(nums) / len(nums)

### 17. Find Minimum Value
nums = [8, 3, 11, 2, 7]
# fill your code here
print(minimum)      # Output: 2

**Solution**
minimum = nums[0]
for num in nums:
    if num < minimum:
        minimum = num

### 18. Replace Negatives with Zero
nums = [4, -2, 6, -1]
result = []
# fill your code here
print(result)      # Output: [4,0,6,0]

**Solution**
for num in nums:
    if num < 0:
        result.append(0)
    else:
        result.append(num)
output =  [0 if num < 0 else num for num in nums]

### 19. Count Words
sentence = "Python makes coding easy"
# fill your code here
print(count)      # Output: 4

**Solution**
count = len(sentence.split())

### 20. Find Missing Letter
letters = ['a', 'b', 'd', 'e']
# fill your code here
print(missing)      # Output: c

**Solution**
for i in range(len(letters)-1):
    if ord(letters[i+1]) - ord(letters[i]) > 1:
        missing = chr(ord(letters[i]) + 1)

### 21. Reverse a List
nums = [1,2,3,4,5]
# fill your code here
print(result)      # Output: [5,4,3,2,1]

**Solution**
result = nums[::-1]

### 22. Find Names Starting with A
names = ["Alice", "Bob", "Andrew", "Tom"]
result = []
# fill your code here
print(result)      # Output: ['Alice','Andrew']

**Solution**
for name in names:
    if name.startswith("A"):
        result.append(name)

### 23. Sum of Even Numbers
nums = [1,2,3,4,5,6]
total = 0
# fill your code here
print(total)      # Output: 12

**Solution**
for num in nums:
    if num % 2 == 0:
        total += num
output = sum(c for c in nums if c % 2 == 0)

### 24. Convert Celsius to Fahrenheit
temps = [0, 20, 30]
result = []
# fill your code here
print(result)      # Output: [32.0, 68.0, 86.0]

**Solution**
for temp in temps:
    result.append(temp * 9/5 + 32)

### 25. Find Index of Target
nums = [5,8,2,9]
target = 2
# fill your code here
print(index)      # Output: 2

**Solution**
for i, num in enumerate(nums):
    if num == target:
        index = i
        break

### 26. Build Initials
name = "John Ronald Reuel Tolkien"
# fill your code here
print(initials)      # Output: JRRT

**Solution**
initials = ""
for word in name.split():
    initials += word[0]

### 27. Count Uppercase Letters
text = "PyTHon"
count = 0
# fill your code here
print(count)      # Output: 3

**Solution**
for ch in text:
    if ch.isupper():
        count += 1

### 28. Find Shortest Word
words = ["elephant", "dog", "cat", "banana"]
# fill your code here
print(shortest)      # Output: dog

**Solution**
shortest = words[0]
for word in words:
    if len(word) < len(shortest):
        shortest = word

### 29. Double Even Numbers
nums = [1,2,3,4]
result = []
# fill your code here
print(result)      # Output: [4,8]

**Solution**
for num in nums:
    if num % 2 == 0:
        result.append(num * 2)

### 30. Check if List Contains Duplicates
nums = [1,2,3,2]
# fill your code here
print(has_duplicates)      # Output: True

**Solution**
has_duplicates = len(nums) != len(set(nums))
### Concepts Covered
* ? `for` loops
* ? `if-else` conditions
* ? Strings and slicing
* ? Lists and list methods
* ? Dictionaries and `.get()`
* ? Sets
* ? `enumerate()`
* ? `sum()`, `max()`, `min()`
* ? String methods (`split`, `capitalize`, `startswith`, `isupper`)
* ? Basic algorithmic thinking suitable for a **1-semester Python interview or lab exam**.

# %% [markdown]
# ## Level 2

# %%
## Python Quiz – Level 2 (Slightly Harder)
**Target:** Students who have completed **1 semester of Python** and are preparing for internships/interviews.
**Rules**
* Each question combines **2–4 Python concepts**.
* Fill only the `# fill your code here` section.
* Most solutions require **6–10 lines of code**.
"* Concepts include loops, dictionaries, sets, strings, functions, `enumerate()`, list comprehensions, and basic problem-solving."

## 1. Find the First Duplicate Element
"nums = [3, 5, 2, 4, 5, 2]"
# fill your code here
print(duplicate)      # Output: 5

### Solution
seen = set()
for num in nums:
    if num in seen:
        duplicate = num
        break
    seen.add(num)

## 2. Group Words by Their Starting Letter
"words = [""apple"", ""ant"", ""banana"", ""bat"", ""cat""]"
groups = {}
# fill your code here
print(groups)
"# {'a': ['apple', 'ant'], 'b': ['banana', 'bat'], 'c': ['cat']}"

### Solution
for word in words:
    first = word[0]
    if first not in groups:
        groups[first] = []
    groups[first].append(word)

## 3. Find the Second Most Frequent Character
"text = ""programming"""
# fill your code here
print(answer)
# Output: r

### Solution
freq = {}
for ch in text:
"    freq[ch] = freq.get(ch, 0) + 1"
"sorted_freq = sorted(freq.items(), key=lambda x: x[1], reverse=True)"
answer = sorted_freq[1][0]

## 4. Find All Pairs With Given Sum
"nums = [1, 5, 7, 2, 3, 4]"
target = 6
pairs = []
# fill your code here
print(pairs)
"# [(1,5), (2,4)]"

### Solution
seen = set()
for num in nums:
    complement = target - num
    if complement in seen:
"        pairs.append((complement, num))"
    seen.add(num)

## 5. Find the Most Common Word
"sentence = ""cat dog cat bird dog cat"""
# fill your code here
print(word)
# Output: cat

### Solution
freq = {}
for w in sentence.split():
"    freq[w] = freq.get(w, 0) + 1"
"word = max(freq, key=freq.get)"

## 6. Check Whether Two Lists Are Rotations
"a = [1,2,3,4]"
"b = [3,4,1,2]"
# fill your code here
print(is_rotation)
# Output: True

### Solution
double = a + a
is_rotation = False
for i in range(len(a)):
    if double[i:i+len(a)] == b:
        is_rotation = True
        break

## 7. Find the Longest Consecutive Sequence Length
"nums = [100,4,200,1,3,2]"
# fill your code here
print(longest)
# Output: 4

### Solution
num_set = set(nums)
longest = 0
for num in num_set:
    if num - 1 not in num_set:
        current = num
        length = 1
        while current + 1 in num_set:
            current += 1
            length += 1
"        longest = max(longest, length)"

## 8. Compress a String
"text = ""aaabbcccc"""
# fill your code here
print(result)
# Output: a3b2c4

### Solution
result = ""
count = 1
"for i in range(1, len(text)+1):"
    if i < len(text) and text[i] == text[i-1]:
        count += 1
    else:
        result += text[i-1] + str(count)
        count = 1

## 9. Find Students Scoring Above Average
"marks = {""A"":70, ""B"":90, ""C"":80, ""D"":60}"
result = []
# fill your code here
print(result)
"# ['B', 'C']"

### Solution
avg = sum(marks.values()) / len(marks)
"for student, score in marks.items():"
    if score > avg:
        result.append(student)

## 10. Merge Two Sorted Lists
"a = [1,4,7]"
"b = [2,3,6]"
merged = []
# fill your code here
print(merged)
"# [1,2,3,4,6,7]"

### Solution
i = j = 0
while i < len(a) and j < len(b):
    if a[i] < b[j]:
        merged.append(a[i])
        i += 1
    else:
        merged.append(b[j])
        j += 1
merged.extend(a[i:])
merged.extend(b[j:])

## 11. Find Missing Letters
"text = ""abdefgh"""
# fill your code here
print(missing)
# Output: c

### Solution
for i in range(len(text)-1):
    if ord(text[i+1]) - ord(text[i]) > 1:
        missing = chr(ord(text[i]) + 1)
        break

## 12. Find All Prime Numbers Up To N
n = 20
primes = []
# fill your code here
print(primes)
"# [2,3,5,7,11,13,17,19]"

### Solution
"for num in range(2, n+1):"
    prime = True
"    for i in range(2, int(num**0.5)+1):"
        if num % i == 0:
            prime = False
            break
    if prime:
        primes.append(num)

## 13. Rotate Matrix 90 Degrees
matrix = [
"    [1,2,3],"
"    [4,5,6],"
"    [7,8,9]"
]
# fill your code here
print(rotated)
"# [[7,4,1],[8,5,2],[9,6,3]]"

### Solution
rotated = []
for col in range(len(matrix[0])):
    row = []
"    for r in range(len(matrix)-1, -1, -1):"
        row.append(matrix[r][col])
    rotated.append(row)

## 14. Find the First Unique Word
"sentence = ""apple banana apple mango banana kiwi"""
# fill your code here
print(answer)
# kiwi

### Solution
words = sentence.split()
freq = {}
for word in words:
"    freq[word] = freq.get(word, 0) + 1"
for word in words:
    if freq[word] == 1:
        answer = word
        break

## 15. Check Balanced Parentheses
"text = ""{[()]}"""
# fill your code here
print(valid)
# True

### Solution
stack = []
"mapping = {"")"":""("", ""]"":""["", ""}"":""{""}"
valid = True
for ch in text:
"    if ch in ""([{"":"
        stack.append(ch)
    else:
        if not stack or stack.pop() != mapping[ch]:
            valid = False
            break
valid = valid and len(stack) == 0

## 16. Find the Intersection Preserving Order
"a = [4,2,3,2,1]"
"b = [2,1]"
# fill your code here
print(result)
"# [2,2,1]"

### Solution
result = []
for num in a:
    if num in b:
        result.append(num)

## 17. Build an Inverted Index
"docs = [""cat dog"", ""dog bird"", ""cat bird""]"
index = {}
# fill your code here
print(index)
"# {'cat':[0,2], 'dog':[0,1], 'bird':[1,2]}"

### Solution
"for i, doc in enumerate(docs):"
    for word in doc.split():
"        index.setdefault(word, []).append(i)"

## 18. Find the Smallest Missing Positive Integer
"nums = [3,4,-1,1]"
# fill your code here
print(answer)
# 2

### Solution
num_set = set(nums)
answer = 1
while answer in num_set:
    answer += 1

## 19. Determine Winner of Election
"votes = [""A"",""B"",""A"",""C"",""B"",""A""]"
# fill your code here
print(winner)
# A

### Solution
count = {}
for vote in votes:
"    count[vote] = count.get(vote, 0) + 1"
"winner = max(count, key=count.get)"

## 20. Find Leaders in an Array
"nums = [16,17,4,3,5,2]"
leaders = []
# fill your code here
print(leaders)
"# [17,5,2]"

### Solution
"max_right = float(""-inf"")"
for num in reversed(nums):
    if num > max_right:
        leaders.append(num)
        max_right = num
leaders.reverse()

## 21. Check Isomorphic Strings
"s = ""egg"""
"t = ""add"""
# fill your code here
print(isomorphic)
# True

### Solution
map1 = {}
map2 = {}
isomorphic = True
"for a, b in zip(s, t):"
"    if map1.get(a, b) != b or map2.get(b, a) != a:"
        isomorphic = False
        break
    map1[a] = b
    map2[b] = a

## 22. Find Subarray With Given Sum
"nums = [1,4,20,3,10,5]"
target = 33
# fill your code here
print(result)
"# (2,4)"

### Solution
left = 0
current = 0
for right in range(len(nums)):
    current += nums[right]
    while current > target:
        current -= nums[left]
        left += 1
    if current == target:
"        result = (left, right)"
        break
        
## 23. Convert Roman Numerals
"roman = ""XIV"""
# fill your code here
print(value)
# 14

### Solution
"values = {'I':1,'V':5,'X':10,'L':50,'C':100}"
value = 0
for i in range(len(roman)-1):
    if values[roman[i]] < values[roman[i+1]]:
        value -= values[roman[i]]
    else:
        value += values[roman[i]]
value += values[roman[-1]]

## 24. Find the Product Except Self
"nums = [1,2,3,4]"
# fill your code here
print(answer)
"# [24,12,8,6]"

### Solution
answer = []
for i in range(len(nums)):
    product = 1
    for j in range(len(nums)):
        if i != j:
            product *= nums[j]
    answer.append(product)

## 25. Find Longest Word With No Repeated Letters
"words = [""apple"",""lamp"",""banana"",""train""]"
# fill your code here
print(answer)
# train

### Solution
"answer = """
for word in words:
    if len(set(word)) == len(word):
        if len(word) > len(answer):
            answer = word

## 26. Find the Top 2 Students
"marks = {""A"":80,""B"":95,""C"":88,""D"":90}"
# fill your code here
print(top2)
"# ['B', 'D']"

### Solution
sorted_students = sorted(
"    marks,"
"    key=marks.get,"
    reverse=True
)
top2 = sorted_students[:2]

## 27. Decode Run-Length Encoding
"encoded = ""a3b2c4"""
# fill your code here
print(decoded)
# aaabbcccc

### Solution
"decoded = """
"for i in range(0, len(encoded), 2):"
    decoded += encoded[i] * int(encoded[i+1])

## 28. Find Maximum Difference
"nums = [7,1,5,3,6,4]"
# fill your code here
print(answer)
# 5

### Solution
minimum = nums[0]
answer = 0
for num in nums:
"    answer = max(answer, num - minimum)"
"    minimum = min(minimum, num)"

## 29. Build Pascal's Triangle Row
n = 5
row = [1]
# fill your code here
print(row)
"# [1,5,10,10,5,1]"

### Solution
"for i in range(1, n + 1):"
    row.append(row[-1] * (n - i + 1) // i)

## 30. Find the Longest Prefix Shared by All Strings
"words = [""flower"", ""flow"", ""flight""]"
# fill your code here
print(prefix)
# fl

### Solution
prefix = words[0]
for word in words[1:]:
    while not word.startswith(prefix):
        prefix = prefix[:-1]
### Concepts Covered
* ? Dictionaries with `.get()` and `.setdefault()`
* ? Sets for O(1) lookup
* ? Nested loops
* ? Sliding window
* ? Stack-based problems
* ? Two-pointer techniques
* ? Matrix manipulation
* ? Frequency counting
* ? Sorting with `key`
* ? String compression and decoding
* ? Prefix/suffix logic
* ? Interview-style problem solving beyond basic syntax
These are very close to the difficulty level of **first internship coding rounds and university practical exams**.

# %% [markdown]
# ## Functions

# %%
## Python Quiz – Functions (Semester 1.5 Level)
**Instructions:** Complete the function by filling the `# fill your code here` section.
"Each problem combines **functions with 2–3 Python concepts** such as loops, dictionaries, strings, lists, and conditionals."

### 1. Return the First Duplicate Number
def first_duplicate(nums):
    seen = set()
    # fill your code here
"print(first_duplicate([3, 5, 2, 4, 5, 2]))     # Output: 5"

### Solution
def first_duplicate(nums):
    seen = set()
    for num in nums:
        if num in seen:
            return num
        seen.add(num)
    return None

### 2. Find Students Above Average
def above_average(marks):
    result = []
    # fill your code here
    return result
"print(above_average({""A"": 70, ""B"": 90, ""C"": 80, ""D"": 60}))"
"# Output: ['B', 'C']"

### Solution
def above_average(marks):
    result = []
    avg = sum(marks.values()) / len(marks)
"    for student, score in marks.items():"
        if score > avg:
            result.append(student)
    return result

### 3. Compress a String
def compress(text):
"    result = """
    count = 1
    # fill your code here
    return result
"print(compress(""aaabbcccc""))      # Output: a3b2c4"

### Solution
def compress(text):
"    result = """
    count = 1
"    for i in range(1, len(text) + 1):"
        if i < len(text) and text[i] == text[i - 1]:
            count += 1
        else:
            result += text[i - 1] + str(count)
            count = 1
    return result

### 4. Find All Prime Numbers Up To N
def get_primes(n):
    primes = []
    # fill your code here
    return primes
print(get_primes(20))
"# Output: [2, 3, 5, 7, 11, 13, 17, 19]"

### Solution
def get_primes(n):
    primes = []
"    for num in range(2, n + 1):"
        prime = True
"        for i in range(2, int(num**0.5) + 1):"
            if num % i == 0:
                prime = False
                break
        if prime:
            primes.append(num)
    return primes

### 5. Find the Most Frequent Word
def most_common(sentence):
    freq = {}
    # fill your code here
    return word
"print(most_common(""cat dog cat bird dog cat""))"
# Output: cat

### Solution
def most_common(sentence):
    freq = {}
    for word in sentence.split():
"        freq[word] = freq.get(word, 0) + 1"
"    return max(freq, key=freq.get)"

### 6. Check Balanced Parentheses
def is_balanced(text):
    stack = []
"    mapping = {"")"":""("", ""]"":""["", ""}"":""{""}"
    # fill your code here
    return True
"print(is_balanced(""{[()]}""))      # Output: True"

### Solution
def is_balanced(text):
    stack = []
"    mapping = {"")"":""("", ""]"":""["", ""}"":""{""}"
    for ch in text:
"        if ch in ""([{"":"
            stack.append(ch)
        else:
            if not stack or stack.pop() != mapping[ch]:
                return False
    return len(stack) == 0

### 7. Find the Longest Word Without Repeated Letters
def longest_unique(words):
"    answer = """
    # fill your code here
    return answer
"print(longest_unique([""apple"", ""lamp"", ""banana"", ""train""]))"
# Output: train

### Solution
def longest_unique(words):
"    answer = """
    for word in words:
        if len(word) == len(set(word)):
            if len(word) > len(answer):
                answer = word
    return answer

### 8. Find Pairs With Target Sum
"def find_pairs(nums, target):"
    seen = set()
    pairs = []
    # fill your code here
    return pairs
"print(find_pairs([1, 5, 7, 2, 3, 4], 6))"
"# Output: [(1, 5), (2, 4)]"

### Solution
"def find_pairs(nums, target):"
    seen = set()
    pairs = []
    for num in nums:
        complement = target - num
        if complement in seen:
"            pairs.append((complement, num))"
        seen.add(num)
    return pairs

### 9. Find the Longest Common Prefix
def common_prefix(words):
    prefix = words[0]
    # fill your code here
    return prefix
"print(common_prefix([""flower"", ""flow"", ""flight""]))"
# Output: fl

### Solution
def common_prefix(words):
    prefix = words[0]
    for word in words[1:]:
        while not word.startswith(prefix):
            prefix = prefix[:-1]
    return prefix

### 10. Group Words by Length
def group_by_length(words):
    groups = {}
    # fill your code here
    return groups
"print(group_by_length([""cat"", ""dog"", ""apple"", ""banana""]))"
"# Output: {3: ['cat', 'dog'], 5: ['apple'], 6: ['banana']}"

### Solution
def group_by_length(words):
    groups = {}
    for word in words:
        length = len(word)
        if length not in groups:
            groups[length] = []
        groups[length].append(word)
    return groups
    
### Concepts Practiced
| Problem | Concepts Used                        |
| ------- | ------------------------------------ |
"| 1       | Functions, Sets, Early Return        |"
"| 2       | Functions, Dictionaries, Loops       |"
"| 3       | Functions, Strings, Counting         |"
"| 4       | Functions, Nested Loops, Prime Logic |"
"| 5       | Functions, Frequency Dictionaries    |"
"| 6       | Functions, Stack, Dictionaries       |"
"| 7       | Functions, Sets, String Logic        |"
"| 8       | Functions, Sets, Two-Sum Pattern     |"
"| 9       | Functions, String Methods, Loops     |"
"| 10      | Functions, Dictionaries, Grouping    |"
"These are the kinds of function-based questions commonly asked in **Python lab exams, university viva rounds, and beginner internship interviews** after one semester of Python."

# %% [markdown]
# ## OOP

# %%
## Python Quiz – Objects, Classes & OOP (Semester 1.5–2 Level)

**Instructions**

* Complete the `# fill your code here` section.
* Each question combines **2–4 OOP concepts** such as constructors, instance variables, methods, inheritance, encapsulation, class variables, and magic methods.
* Try solving before looking at the solution.

## 1. Count Total Objects Created (Class Variable)
class Student:
    count = 0

    def __init__(self, name):
        self.name = name

        # fill your code here

s1 = Student("Alice")
s2 = Student("Bob")
s3 = Student("Charlie")

print(Student.count)      # Output: 3

### Solution
class Student:
    count = 0

    def __init__(self, name):
        self.name = name
        Student.count += 1

## 2. Calculate Area Using Methods
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    # fill your code here

r = Rectangle(4, 5)
print(r.area())          # Output: 20


### Solution
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

## 3. Use Encapsulation
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    # fill your code here

acc = BankAccount(5000)

print(acc.get_balance())     # Output: 5000

### Solution
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def get_balance(self):
        return self.__balance

## 4. Deposit Money
class BankAccount:
    def __init__(self):
        self.balance = 0

    # fill your code here

acc = BankAccount()
acc.deposit(500)

print(acc.balance)      # Output: 500

### Solution
class BankAccount:
    def __init__(self):
        self.balance = 0

    def deposit(self, amount):
        self.balance += amount

## 5. Inheritance – Employee Bonus
class Employee:
    def __init__(self, salary):
        self.salary = salary

class Manager(Employee):

    # fill your code here

m = Manager(50000)

print(m.get_bonus())      # Output: 5000

### Solution
class Manager(Employee):

    def get_bonus(self):
        return self.salary * 0.10

## 6. Method Overriding
class Animal:
    def sound(self):
        return "Some sound"

class Dog(Animal):

    # fill your code here

d = Dog()

print(d.sound())      # Output: Bark

### Solution
class Dog(Animal):

    def sound(self):
        return "Bark"

## 7. String Representation (**str**)
class Book:
    def __init__(self, title):
        self.title = title

    # fill your code here

book = Book("Python Basics")

print(book)
# Output: Book: Python Basics

### Solution
class Book:
    def __init__(self, title):
        self.title = title

    def __str__(self):
        return f"Book: {self.title}"

## 8. Static Method
class Temperature:

    # fill your code here

print(Temperature.celsius_to_fahrenheit(25))
# Output: 77.0


### Solution
class Temperature:

    @staticmethod
    def celsius_to_fahrenheit(c):
        return c * 9/5 + 32


## 9. Class Method Alternative Constructor
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    # fill your code here

s = Student.from_string("Alice-95")

print(s.name, s.marks)
# Output: Alice 95

### Solution
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    @classmethod
    def from_string(cls, text):
        name, marks = text.split("-")
        return cls(name, int(marks))


## 10. Composition – Library and Books
class Book:
    def __init__(self, title):
        self.title = title

class Library:
    def __init__(self):
        self.books = []

    # fill your code here

lib = Library()

lib.add_book(Book("Python"))
lib.add_book(Book("Data Science"))

print([book.title for book in lib.books])
# Output: ['Python', 'Data Science']

### Solution
class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

# Bonus Challenge (Slightly Harder)

## 11. Operator Overloading


class Vector:
    def __init__(self, value):
        self.value = value

    # fill your code here

v1 = Vector(10)
v2 = Vector(20)

print((v1 + v2).value)
# Output: 30


### Solution


class Vector:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        return Vector(self.value + other.value)




# OOP Concepts Covered

| Question | Concepts                                |
| -- |  |
| 1        | Constructors, Class Variables           |
| 2        | Instance Methods                        |
| 3        | Encapsulation, Private Variables        |
| 4        | State Modification                      |
| 5        | Inheritance                             |
| 6        | Method Overriding (Polymorphism)        |
| 7        | Magic Methods (`__str__`)               |
| 8        | Static Methods                          |
| 9        | Class Methods, Alternative Constructors |
| 10       | Composition ("has-a" relationship)      |
| Bonus    | Operator Overloading (`__add__`)        |

These are exactly the types of OOP questions often asked in:

* ✅ First-year/second-year Python practical exams
* ✅ University viva sessions
* ✅ Entry-level internship interviews
* ✅ Python certification assessments.
